# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import seaborn as sns
import xgboost as xgb
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

from IPython.display import Image, display
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

from sklearn.preprocessing import OrdinalEncoder

# %%
train_df = pd.read_csv('/content/train.csv')
transactions_df = pd.read_csv('/content/transactions.csv')
stores_df = pd.read_csv('/content/stores.csv')

train_df = pd.merge(train_df,stores_df,how='left',on='store_nbr')
train_df.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion   city  \
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  Quito
# 1   1  2013-01-01          1   BABY CARE    0.0            0  Quito
# 2   2  2013-01-01          1      BEAUTY    0.0            0  Quito
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  Quito
# 4   4  2013-01-01          1       BOOKS    0.0            0  Quito
#
#        state type  cluster
# 0  Pichincha    D       13
# 1  Pichincha    D       13
# 2  Pichincha    D       13
# 3  Pichincha    D       13
# 4  Pichincha    D       13

# %%
oil_df = pd.read_csv('/content/oil.csv')
oil_df['date'] = pd.to_datetime(oil_df['date'])

oil_df
# Out:
#            date  dcoilwtico
# 0    2013-01-01         NaN
# 1    2013-01-02       93.14
# 2    2013-01-03       92.97
# 3    2013-01-04       93.12
# 4    2013-01-07       93.20
# ...         ...         ...
# 1213 2017-08-25       47.65
# 1214 2017-08-28       46.40
# 1215 2017-08-29       46.46
# 1216 2017-08-30       45.96
# 1217 2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
print(len(train_df.date.unique()) , len(oil_df.date.unique()))

dates_df = pd.DataFrame(train_df.date.unique(), columns=['date'])
dates_df['date'] = pd.to_datetime(dates_df['date'], errors='coerce')
dates_df = dates_df.dropna()  # drop rows with missing dates

oil_df = pd.merge(dates_df, oil_df, how="left", on="date")
oil_df = oil_df.set_index('date')
oil_df.shape
# Out:
# 1684 1218
# (1684, 1)

# %%
print(oil_df.query('dcoilwtico != dcoilwtico'))
print(oil_df.isnull().sum())
print(oil_df.describe())
# Out:
#             dcoilwtico
# date
# 2013-01-01         NaN
# 2013-01-05         NaN
# 2013-01-06         NaN
# 2013-01-12         NaN
# 2013-01-13         NaN
# ...                ...
# 2017-07-30         NaN
# 2017-08-05         NaN
# 2017-08-06         NaN
# 2017-08-12         NaN
# 2017-08-13         NaN
#
# [521 rows x 1 columns]
# dcoilwtico    521
# dtype: int64
#         dcoilwtico
# count  1163.000000
# mean     67.925589
# std      25.677366
# min      26.190000
# 25%      46.390000
# 50%      53.330000
# 75%      95.790000
# max     110.620000

# %%
import plotly.express as px

fig = px.line(oil_df, x = oil_df.index, y ='dcoilwtico', title='Plot slider for oil prices')
fig.update_xaxes(
    rangeslider_visible = True,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6dc4c339-5dab-495f-b27f-343ea8b71ed7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dc4c339-5dab-495f-b27f-343ea8b71ed7")) {                    Plotly.newPlot(                        "6dc4c339-5dab-495f-b27f-343ea8b71ed7",                        [{"hovertemplate":"date=%{x}<br>dcoilwtico=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00: ...

# %%
oil_na = oil_df.copy()
oil_na.dropna()
# Out:
#             dcoilwtico
# date
# 2013-01-02       93.14
# 2013-01-03       92.97
# 2013-01-04       93.12
# 2013-01-07       93.20
# 2013-01-08       93.21
# ...                ...
# 2017-08-09       49.59
# 2017-08-10       48.54
# 2017-08-11       48.81
# 2017-08-14       47.59
# 2017-08-15       47.57
#
# [1163 rows x 1 columns]

# %%
pd.plotting.autocorrelation_plot(oil_na['2015':'2016']['dcoilwtico'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
pd.plotting.autocorrelation_plot(oil_df['2015':'2016']['dcoilwtico'].resample('1m').mean())
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
pd.plotting.lag_plot(oil_df['dcoilwtico'], lag= 1)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
pd.plotting.lag_plot(oil_df['dcoilwtico'], lag= 3)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 3)'>

# %%
pd.plotting.lag_plot(oil_df['dcoilwtico'], lag= 30)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 30)'>

# %%
oil_df['dcoilwtico'][0] = oil_df['dcoilwtico'][1].copy()
oil_df = oil_df.interpolate(method='linear')

# %%
fig = px.line(oil_df, x = oil_df.index, y ='dcoilwtico', title='Plot slider for oil prices')
fig.update_xaxes(
    rangeslider_visible = True,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="631c3c72-e85e-4575-9d02-dcbe5ef8a678" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("631c3c72-e85e-4575-9d02-dcbe5ef8a678")) {                    Plotly.newPlot(                        "631c3c72-e85e-4575-9d02-dcbe5ef8a678",                        [{"hovertemplate":"date=%{x}<br>dcoilwtico=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00: ...

# %%
train_df['date'] = pd.to_datetime(train_df['date'], errors="coerce")
train_df=train_df.dropna()
train_df = train_df.set_index('date')

# %%
train_df.groupby(['city']).sales.mean().plot(kind='bar');

# %%
train_df.groupby('store_nbr')[['onpromotion','sales']].sum().plot.scatter('onpromotion','sales')
plt.title('Promotion and Sales Relationship')
# Out:
# Text(0.5, 1.0, 'Promotion and Sales Relationship')

# %%
train_df = pd.merge(train_df,oil_df,how='left',on='date')

# %%
print(train_df.query('dcoilwtico !=dcoilwtico'))
# Out:
# Empty DataFrame
# Columns: [id, store_nbr, family, sales, onpromotion, city, state, type, cluster, dcoilwtico]
# Index: []

# %%
grouped = train_df.groupby(['date']).agg({'dcoilwtico': 'mean', 'sales': 'mean'})
fig = px.line(grouped, x=grouped.index , y=['sales', 'dcoilwtico'])
fig.update_layout(title='Sale and Date Plot')
fig.show()
del grouped
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="53e75951-434e-4447-8bc5-587cca7b8e4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53e75951-434e-4447-8bc5-587cca7b8e4e")) {                    Plotly.newPlot(                        "53e75951-434e-4447-8bc5-587cca7b8e4e",                        [{"hovertemplate":"variable=sales<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"sales","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"sales","showlegend":true,"x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00: ...

# %%
train_df.head()
# Out:
#             id  store_nbr      family  sales  onpromotion   city      state  \
# date
# 2013-01-01   0          1  AUTOMOTIVE    0.0            0  Quito  Pichincha
# 2013-01-01   1          1   BABY CARE    0.0            0  Quito  Pichincha
# 2013-01-01   2          1      BEAUTY    0.0            0  Quito  Pichincha
# 2013-01-01   3          1   BEVERAGES    0.0            0  Quito  Pichincha
# 2013-01-01   4          1       BOOKS    0.0            0  Quito  Pichincha
#
#            type  cluster  dcoilwtico
# date
# 2013-01-01    D       13       93.14
# 2013-01-01    D       13       93.14
# 2013-01-01    D       13       93.14
# 2013-01-01    D       13       93.14
# 2013-01-01    D       13       93.14

# %%
holidays_df = pd.read_csv('/content/holidays_events.csv')

holidays_df = holidays_df[holidays_df['transferred'] == False].copy()
holidays_df['holiday_type'] = holidays_df['type']
holidays_df.drop(['transferred', 'description', 'type'], axis=1, inplace=True)

national_holidays = holidays_df[holidays_df['locale'] == 'National'].copy()
national_holidays['national_holiday_type'] = national_holidays['holiday_type']
national_holidays.drop(['locale', 'locale_name', 'holiday_type'], axis=1, inplace=True)
national_holidays.drop_duplicates(subset='date', keep="first", inplace=True)
national_holidays['date'] = pd.to_datetime(national_holidays['date'])
train_df = pd.merge(train_df, national_holidays, how='left', on=['date'])
state_holidays = holidays_df[holidays_df['locale'] == 'Regional'].copy()
state_holidays['state'] = state_holidays['locale_name']
state_holidays['state_holiday_type'] = state_holidays['holiday_type']
state_holidays.drop(['locale', 'locale_name', 'holiday_type'], axis=1, inplace=True)
state_holidays['date'] = pd.to_datetime(state_holidays['date'])
train_df = pd.merge(train_df, state_holidays, how='left', on=['date', 'state'])

city_holidays = holidays_df[holidays_df['locale'] == 'Local'].copy()
city_holidays['city'] = city_holidays['locale_name']
city_holidays['city_holiday_type'] = city_holidays['holiday_type']
city_holidays.drop(['locale', 'locale_name', 'holiday_type'], axis=1, inplace=True)
city_holidays.drop([265], axis=0, inplace=True)
city_holidays['date'] = pd.to_datetime(city_holidays['date'])
train_df = pd.merge(train_df, city_holidays, how='left', on=['date', 'city'])

del city_holidays
del state_holidays
del national_holidays

train_df.head()
# Out:
#         date  id  store_nbr      family  sales  onpromotion   city      state  \
# 0 2013-01-01   0          1  AUTOMOTIVE    0.0            0  Quito  Pichincha
# 1 2013-01-01   1          1   BABY CARE    0.0            0  Quito  Pichincha
# 2 2013-01-01   2          1      BEAUTY    0.0            0  Quito  Pichincha
# 3 2013-01-01   3          1   BEVERAGES    0.0            0  Quito  Pichincha
# 4 2013-01-01   4          1       BOOKS    0.0            0  Quito  Pichincha
#
#   type  cluster  dcoilwtico national_holiday_type state_holiday_type  \
# 0    D       13       93.14               Holiday                NaN
# 1    D       13       93.14               Holiday                NaN
# 2    D       13       93.14               Holiday                NaN
# 3    D       13       93.14               Holiday                NaN
# 4    D       13       93.14               Holiday                NaN
#
#   city_holiday_type
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
train_df.fillna('', inplace=True)

# %%
ordinal_encoder = OrdinalEncoder(dtype=int)
train_df[['family']] = ordinal_encoder.fit_transform(train_df[['family']])
train_df[['national_holiday_type']] = ordinal_encoder.fit_transform(train_df[['national_holiday_type']])
train_df[['state_holiday_type']] = ordinal_encoder.fit_transform(train_df[['state_holiday_type']])
train_df[['city_holiday_type']] = ordinal_encoder.fit_transform(train_df[['city_holiday_type']])

# %%
del train_df['city']
del train_df['state']
del train_df['type']
train_df.head()
# Out:
#         date  id  store_nbr  family  sales  onpromotion  cluster  dcoilwtico  \
# 0 2013-01-01   0          1       0    0.0            0       13       93.14
# 1 2013-01-01   1          1       1    0.0            0       13       93.14
# 2 2013-01-01   2          1       2    0.0            0       13       93.14
# 3 2013-01-01   3          1       3    0.0            0       13       93.14
# 4 2013-01-01   4          1       4    0.0            0       13       93.14
#
#    national_holiday_type  state_holiday_type  city_holiday_type
# 0                      4                   0                  0
# 1                      4                   0                  0
# 2                      4                   0                  0
# 3                      4                   0                  0
# 4                      4                   0                  0

# %%
import seaborn as sns

# Compute the correlation matrix
corr_matrix = train_df.corr()

# Create a heatmap using seaborn
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f')
# Out:
# <ipython-input-26-c79fd6c2bc40>:4: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %%
grouped_df = train_df.groupby(['date']).agg({'sales': 'sum','dcoilwtico': 'mean', 
                                                 'onpromotion': 'sum',
                                                 'national_holiday_type': 'mean',
                                                 'city_holiday_type': 'mean',
                                                 'state_holiday_type': 'mean'})

grouped_df.head()
# Out:
#                     sales  dcoilwtico  onpromotion  national_holiday_type  \
# date
# 2013-01-01    2511.618999   93.140000            0                    4.0
# 2013-01-02  496092.417944   93.140000            0                    0.0
# 2013-01-03  361461.231124   92.970000            0                    0.0
# 2013-01-04  354459.677093   93.120000            0                    0.0
# 2013-01-05  477350.121229   93.146667            0                    6.0
#
#             city_holiday_type  state_holiday_type
# date
# 2013-01-01                0.0                 0.0
# 2013-01-02                0.0                 0.0
# 2013-01-03                0.0                 0.0
# 2013-01-04                0.0                 0.0
# 2013-01-05                0.0                 0.0

# %%
scaler  = MinMaxScaler()
scaled_grouped_df = scaler.fit_transform(grouped_df)
scaled_grouped_df.shape
# Out:
# (1684, 6)

# %%
features = scaled_grouped_df
target = scaled_grouped_df[:,0]

features.shape
# Out:
# (1684, 6)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state= 4, shuffle= False)

# %%
win_length = 50
batch_size = 32
input_features = 6  

# create timeseries generators for train and test data
train_generator = TimeseriesGenerator(features, target, length=win_length,
                                      sampling_rate=1, batch_size=batch_size)
test_generator = TimeseriesGenerator(features, target, length=win_length,
                                     sampling_rate=1, batch_size=batch_size)

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv1D(filters=32, kernel_size=5, activation='relu', input_shape=(win_length, input_features)))
model.add(tf.keras.layers.MaxPooling1D(pool_size=2))
model.add(tf.keras.layers.Conv1D(filters=64, kernel_size=5, activation='relu'))
model.add(tf.keras.layers.MaxPooling1D(pool_size=2))
model.add(tf.keras.layers.Conv1D(filters=128, kernel_size=5, activation='relu'))
model.add(tf.keras.layers.MaxPooling1D(pool_size=2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(1))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 46, 32)            992
#
#  max_pooling1d (MaxPooling1D  (None, 23, 32)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 19, 64)            10304
#
#  max_pooling1d_1 (MaxPooling  (None, 9, 64)            0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 128)            41088
#
#  max_pooling1d_2 (MaxPooling  (None, 2, 128)           0
#  1D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 68,897
# Trainable params: 68,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss= tf.losses.MeanSquaredError(),
             optimizer= tf.optimizers.Adam(),
             metrics =[tf.metrics.MeanAbsoluteError()])


history = model.fit(train_generator, epochs =100,
                              validation_data= test_generator,
                              shuffle = False)
# Out:
# Epoch 1/100
# 52/52 [==============================] - 7s 20ms/step - loss: 0.0279 - mean_absolute_error: 0.1319 - val_loss: 0.0317 - val_mean_absolute_error: 0.1429
# Epoch 2/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0262 - mean_absolute_error: 0.1279 - val_loss: 0.1684 - val_mean_absolute_error: 0.3138
# Epoch 3/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0572 - mean_absolute_error: 0.1905 - val_loss: 0.0898 - val_mean_absolute_error: 0.2345
# Epoch 4/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0436 - mean_absolute_error: 0.1650 - val_loss: 0.0530 - val_mean_absolute_error: 0.1912
# Epoch 5/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0285 - mean_absolute_error: 0.1319 - val_loss: 0.0857 - val_mean_absolute_error: 0.2336
# Epoch 6/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0408 - mean_absolute_error: 0.1621 - val_loss: 0.0311 - val_mean_absolute_error: 0.1526
# Epoch 7/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0227 - mean_absolute_error: 0.1192 - val_loss: 0.0236 - val_mean_absolute_error: 0.1296
# Epoch 8/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0193 - mean_absolute_error: 0.1096 - val_loss: 0.0213 - val_mean_absolute_error: 0.1214
# Epoch 9/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0181 - mean_absolute_error: 0.1053 - val_loss: 0.0178 - val_mean_absolute_error: 0.1102
# Epoch 10/100
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0177 - mean_absolute_error: 0.1039 - val_loss: 0.0145 - val_mean_absolute_error: 0.0976
# Epoch 11/100
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0167 - mean_absolute_error: 0.1008 - val_loss: 0.0128 - val_mean_absolute_error: 0.0904
# Epoch 12/100
# 52/52 [==============================] - 1s 24ms/step - loss: 0.0161 - mean_absolute_error: 0.0966 - val_loss: 0.0117 - val_mean_absolute_error: 0.0862
# Epoch 13/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0138 - mean_absolute_error: 0.0905 - val_loss: 0.0129 - val_mean_absolute_error: 0.0948
# Epoch 14/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0145 - mean_absolute_error: 0.0946 - val_loss: 0.0107 - val_mean_absolute_error: 0.0836
# Epoch 15/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0129 - mean_absolute_error: 0.0869 - val_loss: 0.0119 - val_mean_absolute_error: 0.0910
# Epoch 16/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0127 - mean_absolute_error: 0.0872 - val_loss: 0.0122 - val_mean_absolute_error: 0.0925
# Epoch 17/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0123 - mean_absolute_error: 0.0864 - val_loss: 0.0230 - val_mean_absolute_error: 0.1305
# Epoch 18/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0127 - mean_absolute_error: 0.0886 - val_loss: 0.0126 - val_mean_absolute_error: 0.0930
# Epoch 19/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0109 - mean_absolute_error: 0.0815 - val_loss: 0.0110 - val_mean_absolute_error: 0.0862
# Epoch 20/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0105 - mean_absolute_error: 0.0799 - val_loss: 0.0099 - val_mean_absolute_error: 0.0816
# Epoch 21/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0108 - mean_absolute_error: 0.0804 - val_loss: 0.0076 - val_mean_absolute_error: 0.0699
# Epoch 22/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0098 - mean_absolute_error: 0.0769 - val_loss: 0.0083 - val_mean_absolute_error: 0.0719
# Epoch 23/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0094 - mean_absolute_error: 0.0745 - val_loss: 0.0063 - val_mean_absolute_error: 0.0617
# Epoch 24/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0088 - mean_absolute_error: 0.0721 - val_loss: 0.0064 - val_mean_absolute_error: 0.0628
# Epoch 25/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0096 - mean_absolute_error: 0.0767 - val_loss: 0.0060 - val_mean_absolute_error: 0.0608
# Epoch 26/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0095 - mean_absolute_error: 0.0762 - val_loss: 0.0076 - val_mean_absolute_error: 0.0726
# Epoch 27/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0090 - mean_absolute_error: 0.0733 - val_loss: 0.0071 - val_mean_absolute_error: 0.0687
# Epoch 28/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0082 - mean_absolute_error: 0.0699 - val_loss: 0.0086 - val_mean_absolute_error: 0.0785
# Epoch 29/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0077 - mean_absolute_error: 0.0681 - val_loss: 0.0050 - val_mean_absolute_error: 0.0575
# Epoch 30/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0066 - mean_absolute_error: 0.0632 - val_loss: 0.0042 - val_mean_absolute_error: 0.0509
# Epoch 31/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0067 - mean_absolute_error: 0.0644 - val_loss: 0.0051 - val_mean_absolute_error: 0.0588
# Epoch 32/100
# 52/52 [==============================] - 1s 9ms/step - loss: 0.0069 - mean_absolute_error: 0.0647 - val_loss: 0.0041 - val_mean_absolute_error: 0.0498
# Epoch 33/100
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0066 - mean_absolute_error: 0.0625 - val_loss: 0.0044 - val_mean_absolute_error: 0.0484
# Epoch 34/100
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0063 - mean_absolute_error: 0.0609 - val_loss: 0.0040 - val_mean_absolute_error: 0.0486
# Epoch 35/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0070 - mean_absolute_error: 0.0645 - val_loss: 0.0040 - val_mean_absolute_error: 0.0487
# Epoch 36/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0062 - mean_absolute_error: 0.0615 - val_loss: 0.0046 - val_mean_absolute_error: 0.0504
# Epoch 37/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0058 - mean_absolute_error: 0.0576 - val_loss: 0.0038 - val_mean_absolute_error: 0.0476
# Epoch 38/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0073 - mean_absolute_error: 0.0648 - val_loss: 0.0064 - val_mean_absolute_error: 0.0650
# Epoch 39/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0070 - mean_absolute_error: 0.0646 - val_loss: 0.0093 - val_mean_absolute_error: 0.0786
# Epoch 40/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0073 - mean_absolute_error: 0.0662 - val_loss: 0.0075 - val_mean_absolute_error: 0.0733
# Epoch 41/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0066 - mean_absolute_error: 0.0634 - val_loss: 0.0036 - val_mean_absolute_error: 0.0449
# Epoch 42/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0056 - mean_absolute_error: 0.0584 - val_loss: 0.0046 - val_mean_absolute_error: 0.0505
# Epoch 43/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0056 - mean_absolute_error: 0.0571 - val_loss: 0.0046 - val_mean_absolute_error: 0.0509
# Epoch 44/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0059 - mean_absolute_error: 0.0591 - val_loss: 0.0043 - val_mean_absolute_error: 0.0512
# Epoch 45/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0062 - mean_absolute_error: 0.0611 - val_loss: 0.0042 - val_mean_absolute_error: 0.0517
# Epoch 46/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0059 - mean_absolute_error: 0.0590 - val_loss: 0.0064 - val_mean_absolute_error: 0.0661
# Epoch 47/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0054 - mean_absolute_error: 0.0563 - val_loss: 0.0041 - val_mean_absolute_error: 0.0520
# Epoch 48/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0049 - mean_absolute_error: 0.0538 - val_loss: 0.0035 - val_mean_absolute_error: 0.0482
# Epoch 49/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0047 - mean_absolute_error: 0.0526 - val_loss: 0.0030 - val_mean_absolute_error: 0.0404
# Epoch 50/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0047 - mean_absolute_error: 0.0529 - val_loss: 0.0057 - val_mean_absolute_error: 0.0554
# Epoch 51/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0050 - mean_absolute_error: 0.0539 - val_loss: 0.0036 - val_mean_absolute_error: 0.0473
# Epoch 52/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0053 - mean_absolute_error: 0.0563 - val_loss: 0.0035 - val_mean_absolute_error: 0.0455
# Epoch 53/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0043 - mean_absolute_error: 0.0500 - val_loss: 0.0032 - val_mean_absolute_error: 0.0453
# Epoch 54/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0043 - mean_absolute_error: 0.0503 - val_loss: 0.0030 - val_mean_absolute_error: 0.0442
# Epoch 55/100
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0038 - mean_absolute_error: 0.0474 - val_loss: 0.0025 - val_mean_absolute_error: 0.0392
# Epoch 56/100
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0040 - mean_absolute_error: 0.0483 - val_loss: 0.0046 - val_mean_absolute_error: 0.0564
# Epoch 57/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0041 - mean_absolute_error: 0.0496 - val_loss: 0.0029 - val_mean_absolute_error: 0.0435
# Epoch 58/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0041 - mean_absolute_error: 0.0501 - val_loss: 0.0034 - val_mean_absolute_error: 0.0438
# Epoch 59/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0043 - mean_absolute_error: 0.0512 - val_loss: 0.0042 - val_mean_absolute_error: 0.0487
# Epoch 60/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0045 - mean_absolute_error: 0.0515 - val_loss: 0.0045 - val_mean_absolute_error: 0.0508
# Epoch 61/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0048 - mean_absolute_error: 0.0532 - val_loss: 0.0036 - val_mean_absolute_error: 0.0466
# Epoch 62/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0046 - mean_absolute_error: 0.0528 - val_loss: 0.0045 - val_mean_absolute_error: 0.0503
# Epoch 63/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0043 - mean_absolute_error: 0.0501 - val_loss: 0.0041 - val_mean_absolute_error: 0.0505
# Epoch 64/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0042 - mean_absolute_error: 0.0491 - val_loss: 0.0034 - val_mean_absolute_error: 0.0467
# Epoch 65/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0043 - mean_absolute_error: 0.0506 - val_loss: 0.0062 - val_mean_absolute_error: 0.0622
# Epoch 66/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0044 - mean_absolute_error: 0.0507 - val_loss: 0.0034 - val_mean_absolute_error: 0.0467
# Epoch 67/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0040 - mean_absolute_error: 0.0482 - val_loss: 0.0029 - val_mean_absolute_error: 0.0437
# Epoch 68/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0042 - mean_absolute_error: 0.0498 - val_loss: 0.0027 - val_mean_absolute_error: 0.0417
# Epoch 69/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0043 - mean_absolute_error: 0.0505 - val_loss: 0.0046 - val_mean_absolute_error: 0.0488
# Epoch 70/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0046 - mean_absolute_error: 0.0530 - val_loss: 0.0039 - val_mean_absolute_error: 0.0468
# Epoch 71/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0046 - mean_absolute_error: 0.0521 - val_loss: 0.0050 - val_mean_absolute_error: 0.0522
# Epoch 72/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0048 - mean_absolute_error: 0.0537 - val_loss: 0.0049 - val_mean_absolute_error: 0.0535
# Epoch 73/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0051 - mean_absolute_error: 0.0550 - val_loss: 0.0041 - val_mean_absolute_error: 0.0516
# Epoch 74/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0046 - mean_absolute_error: 0.0518 - val_loss: 0.0114 - val_mean_absolute_error: 0.0864
# Epoch 75/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0064 - mean_absolute_error: 0.0624 - val_loss: 0.0114 - val_mean_absolute_error: 0.0916
# Epoch 76/100
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0057 - mean_absolute_error: 0.0594 - val_loss: 0.0036 - val_mean_absolute_error: 0.0482
# Epoch 77/100
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0036 - mean_absolute_error: 0.0473 - val_loss: 0.0027 - val_mean_absolute_error: 0.0381
# Epoch 78/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0038 - mean_absolute_error: 0.0470 - val_loss: 0.0022 - val_mean_absolute_error: 0.0369
# Epoch 79/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0032 - mean_absolute_error: 0.0444 - val_loss: 0.0025 - val_mean_absolute_error: 0.0388
# Epoch 80/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - val_loss: 0.0049 - val_mean_absolute_error: 0.0540
# Epoch 81/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0439 - val_loss: 0.0034 - val_mean_absolute_error: 0.0463
# Epoch 82/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0039 - mean_absolute_error: 0.0490 - val_loss: 0.0028 - val_mean_absolute_error: 0.0421
# Epoch 83/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - val_loss: 0.0037 - val_mean_absolute_error: 0.0488
# Epoch 84/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0037 - mean_absolute_error: 0.0464 - val_loss: 0.0036 - val_mean_absolute_error: 0.0496
# Epoch 85/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0040 - mean_absolute_error: 0.0490 - val_loss: 0.0025 - val_mean_absolute_error: 0.0388
# Epoch 86/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0037 - mean_absolute_error: 0.0472 - val_loss: 0.0043 - val_mean_absolute_error: 0.0481
# Epoch 87/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_absolute_error: 0.0444 - val_loss: 0.0046 - val_mean_absolute_error: 0.0529
# Epoch 88/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0036 - mean_absolute_error: 0.0462 - val_loss: 0.0053 - val_mean_absolute_error: 0.0568
# Epoch 89/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_absolute_error: 0.0444 - val_loss: 0.0056 - val_mean_absolute_error: 0.0593
# Epoch 90/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0043 - mean_absolute_error: 0.0504 - val_loss: 0.0066 - val_mean_absolute_error: 0.0658
# Epoch 91/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0038 - mean_absolute_error: 0.0480 - val_loss: 0.0027 - val_mean_absolute_error: 0.0413
# Epoch 92/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0038 - mean_absolute_error: 0.0483 - val_loss: 0.0033 - val_mean_absolute_error: 0.0431
# Epoch 93/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0032 - mean_absolute_error: 0.0443 - val_loss: 0.0054 - val_mean_absolute_error: 0.0555
# Epoch 94/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0035 - mean_absolute_error: 0.0454 - val_loss: 0.0044 - val_mean_absolute_error: 0.0533
# Epoch 95/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0036 - mean_absolute_error: 0.0468 - val_loss: 0.0063 - val_mean_absolute_error: 0.0651
# Epoch 96/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0040 - mean_absolute_error: 0.0493 - val_loss: 0.0042 - val_mean_absolute_error: 0.0519
# Epoch 97/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0034 - mean_absolute_error: 0.0446 - val_loss: 0.0027 - val_mean_absolute_error: 0.0407
# Epoch 98/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 0.0033 - val_mean_absolute_error: 0.0455
# Epoch 99/100
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0029 - mean_absolute_error: 0.0409 - val_loss: 0.0023 - val_mean_absolute_error: 0.0377
# Epoch 100/100
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0419 - val_loss: 0.0028 - val_mean_absolute_error: 0.0412

# %%
 plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.legend()
plt.show()

# %%
mae = history.history['mean_absolute_error']
val_mae = history.history['val_mean_absolute_error']
epochs = range(1, len(mae) + 1)

plt.plot(epochs, mae, 'bo', label='Training MAE')
plt.plot(epochs, val_mae, 'b', label='Validation MAE')
plt.title('Training and validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
model.evaluate(test_generator, verbose = 0)
# Out:
# [0.002758789574727416, 0.04117685556411743]

# %%
predictions = model.predict(test_generator)
# Out:
# 52/52 [==============================] - 0s 3ms/step

# %%
df_pred = pd.concat([pd.DataFrame(predictions), pd.DataFrame(X_test[:,1:][win_length:])], axis = 1)
rev_trans = scaler.inverse_transform(df_pred)

# %%
df_final = grouped_df[predictions.shape[0]*-1:].copy()

# %%
df_final.count()
# Out:
# sales                    1634
# dcoilwtico               1634
# onpromotion              1634
# national_holiday_type    1634
# city_holiday_type        1634
# state_holiday_type       1634
# dtype: int64

# %%
df_final['predictions'] = rev_trans[:,0]

# %%
df_final[['sales','predictions']].plot()
# Out:
# <Axes: xlabel='date'>
